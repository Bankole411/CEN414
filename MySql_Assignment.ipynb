# %%
import pandas as pd

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="4789", 
     database="assignment"
)

print(mydb)

mycursor = mydb.cursor()

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="4789", 
     database="assignment"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM assignment.data")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Afghanistan', 2007, 'All genders', 'Not applicable', 'Percent', 28.04189)
# ('Afghanistan', 2013, 'All genders', 'Not applicable', 'Percent', 48.87529)
# ('Afghanistan', 2014, 'All genders', 'Not applicable', 'Percent', 48.75032)
# ('Afghanistan', 1993, 'All genders', 'Not applicable', 'Percent', 15.55174)
# ('Albania', 2000, 'All genders', 'Not applicable', 'Percent', 67.04211)
# ('Albania', 2001, 'All genders', 'Not applicable', 'Percent', 68.75755)
# ('Albania', 2013, 'All genders', 'Not applicable', 'Percent', 84.02378)
# ('Albania', 2014, 'All genders', 'Not applicable', 'Percent', 85.27821)
# ('Algeria', 1984, 'All genders', 'Not applicable', 'Percent', 38.77885)
# ('Algeria', 1995, 'All genders', 'Not applicable', 'Percent', 52.24994)
# ('Algeria', 1996, 'All genders', 'Not applicable', 'Percent', 52.75815)
# ('Algeria', 1997, 'All genders', 'Not applicable', 'Percent', 52.61339)
# ('Angola', 1982, 'All genders', 'Not applicable', 'Percent', 5.8063)
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="4789", 
     database="assignment"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM assignment.data WHERE country IN ('Algeria','Angola','Benin','Botswana','Burkina Faso','Burundi','Cameroon','Cape Verde','Central African Republic','Chad','Comoros','Democratic Republic of the Congo','Djibouti','Egypt','Equatorial Guinea','Eritrea','Eswatini','Ethiopia','Gabon','Gambia','Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Libyan Arab Jamahiriya','Madagascar','Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda','Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia','Uganda''Zambia','Zimbabwe')"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
#Fetch Command---African countries From database
# Out:
# ('Algeria', 1984, 'All genders', 'Not applicable', 'Percent', 38.77885)
# ('Algeria', 1995, 'All genders', 'Not applicable', 'Percent', 52.24994)
# ('Algeria', 1996, 'All genders', 'Not applicable', 'Percent', 52.75815)
# ('Algeria', 1997, 'All genders', 'Not applicable', 'Percent', 52.61339)
# ('Angola', 1982, 'All genders', 'Not applicable', 'Percent', 5.8063)
# ('Angola', 2008, 'All genders', 'Not applicable', 'Percent', 10.1277)
# ('Angola', 2009, 'All genders', 'Not applicable', 'Percent', 10.60603)
# ('Angola', 2010, 'All genders', 'Not applicable', 'Percent', 12.37506)
# ('Benin', 2000, 'All genders', 'Not applicable', 'Percent', 17.25822)
# ('Benin', 2001, 'All genders', 'Not applicable', 'Percent', 18.64569)
# ('Benin', 2013, 'All genders', 'Not applicable', 'Percent', 42.03142)
# ('Botswana', 1980, 'All genders', 'Not applicable', 'Percent', 14.18821)
# ('Botswana', 1981, 'All genders', 'Not applicable', 'Percent', 15.3452)
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="4789", 
     database="assignment"
)

mycursor = mydb.cursor()

sql = "DELETE FROM data WHERE `Time Period` = '1978'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
#Modify---Records deletion
# Out:
# 40 record(s) deleted

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="4789", 
     database="assignment"
)

mycursor = mydb.cursor()

sql = "UPDATE data SET `Time Period` = '2002' WHERE `Time Period` = '1979'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
#Modify----Records Updated
# Out:
# 41 record(s) affected
